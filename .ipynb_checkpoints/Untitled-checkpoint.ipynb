# %%
import json
import csv
import tweepy
import re
import numpy as np
import pandas as pd

# %%
# TO GET ALL DATA


import GetOldTweets3 as got
import pandas as pd


def get_tweets(state, startdate, enddate, maxtweet):
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch("covid19india,lockdown")\
                                            .setSince(startdate)\
                                            .setUntil(enddate)\
                                            .setNear(state)\
                                            .setWithin("13mi")\
                                            .setMaxTweets(maxtweet)
    tweet = got.manager.TweetManager.getTweets(tweetCriteria)
    
    text_tweets = [[tw.username,
                tw.text,
                tw.date,
                #tw.retweets,
                #tw.favorites,
                #tw.mentions,
                tw.hashtags] for tw in tweet]
    df_state= pd.DataFrame(text_tweets, columns = ['User', 'Text', 'Date','Hashtags'])
    
    return df_state
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8944528f6b85> in <module>()
#       1 df_e1 = get_tweets('17.3850° N, 78.4867° E', "2020-01-01", "2020-02-01", 5000) #before lockdown
#       2 df_e2 = get_tweets('17.3850° N, 78.4867° E', "2020-02-01", "2020-03-01", 5000)
# ----> 3 df_e3 = get_tweets('17.3850° N, 78.4867° E', "2020-03-01", "2020-04-01", 5000)
#       4 df_e4 = get_tweets('17.3850° N, 78.4867° E', "2020-04-01", "2020-05-01", 5000)
#       5 df_e5 = get_tweets('17.3850° N, 78.4867° E', "2020-05-01", "2020-06-01", 5000)
#
# <ipython-input-1-b0d35ee55a77> in get_tweets(state, startdate, enddate, maxtweet)
#       8 def get_tweets(state, startdate, enddate, maxtweet):
#       9     tweetCriteria = got.manager.TweetCriteria().setQuerySearch("covid19india,lockdown")                                            .setSince(startdate)                                            .setUntil(enddate)                                            .setNear(state)                                            .setWithin("13mi")                                            .setMaxTweets(maxtweet)
# ---> 10     tweet = got.manager.TweetManager.getTweets(tweetCriteria)
#      11
#      12     text_tweets = [[tw.username,
#
# /anaconda3/lib/python3.6/site-packages/GetOldTweets3/manager/TweetManager.py in getTweets(tweetCriteria, receiveBuffer, bufferLength, proxy, debug)
#      63             active = True
#      64             while active:
# ---> 65                 json = TweetManager.getJsonResponse(tweetCriteria, refreshCursor, cookieJar, proxy, user_agent, debug=debug)
#      66                 if len(json['items_html'].strip()) == 0:
#      67                     break
#
# /anaconda3/lib/python3.6/site-packages/GetOldTweets3/manager/TweetManager.py in getJsonResponse(tweetCriteria, refreshCursor, cookieJar, proxy, useragent, debug)
#     342         try:
#     343             response = opener.open(url)
# --> 344             jsonResponse = response.read()
#     345         except Exception as e:
#     346             print("An error occured during an HTTP request:", str(e))
#
# /anaconda3/lib/python3.6/http/client.py in read(self, amt)
#     460             else:
#     461                 try:
# --> 462                     s = self._safe_read(self.length)
#     463                 except IncompleteRead:
#     464                     self._close_conn()
#
# /anaconda3/lib/python3.6/http/client.py in _safe_read(self, amt)
#     610         s = []
#     611         while amt > 0:
# --> 612             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     613             if not chunk:
#     614                 raise IncompleteRead(b''.join(s), amt)
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df_e1 = get_tweets('17.3850° N, 78.4867° E', "2020-01-01", "2020-02-01", 5000) #before lockdown
df_e2 = get_tweets('17.3850° N, 78.4867° E', "2020-02-01", "2020-03-01", 5000)
df_e3 = get_tweets('17.3850° N, 78.4867° E', "2020-03-01", "2020-04-01", 5000)
df_e4 = get_tweets('17.3850° N, 78.4867° E', "2020-04-01", "2020-05-01", 5000)
df_e5 = get_tweets('17.3850° N, 78.4867° E', "2020-05-01", "2020-06-01", 5000)
df_e6 = get_tweets('17.3850° N, 78.4867° E', "2020-06-01", "2020-07-01", 5000)
df_e7 = get_tweets('17.3850° N, 78.4867° E', "2020-07-01", "2020-08-01", 5000)
hyderabad =  pd.concat([df_e1,df_e2,df_e3,df_e4,df_e5,df_e6,df_e7], ignore_index=True)
hyderabad.head(10)
hyderabad.to_csv('hyderabad.csv')

# get sorted array
data = pd.read_csv("hyderabad.csv")
df = pd.DataFrame(data)
df = df.sort_values(by =['User'])
df.to_csv("hyderabad-cl.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6417298ac1fb> in <module>()
#       1 # get sorted array
# ----> 2 data = pd.read_csv("hyderabad.csv")
#       3 df = pd.DataFrame(data)
#       4 df = df.sort_values(by =['User'])
#       5 df.to_csv("hyderabad-cl.csv")
#
# NameError: name 'pd' is not defined

# %%
#to get unique users 
data = pd.read_csv("hyderabad.csv")
data = pd.DataFrame(data)
all_users = data["User"].unique()

# %%
# get the news dataset ie. list of unique news accounts
news_accounts = pd.read_csv("hyderabad-news.csv")
news = pd.DataFrame(news_accounts["User"].unique(), columns =['Users','Text'])
news.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1653                 blocks = [
# -> 1654                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1655                 ]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3046
# -> 3047     return klass(values, ndim=ndim, placement=placement)
#    3048
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#    2594
# -> 2595         super().__init__(values, ndim=ndim, placement=placement)
#    2596
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     124             raise ValueError(
# --> 125                 f"Wrong number of items passed {len(self.values)}, "
#     126                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 1, placement implies 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-dff87758a1c6> in <module>()
#       1 # get the news dataset ie. list of unique news accounts
#       2 news_accounts = pd.read_csv("hyderabad-news.csv")
# ----> 3 news = pd.DataFrame(news_accounts["User"].unique(), columns =['Users','Text'])
#       4 news.head()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     462                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     463             else:
# --> 464                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     465
#     466         # For data is list-like, or Iterable (will consume into list)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     208         block_values = [values]
#     209
# --> 210     return create_block_manager_from_blocks(block_values, [columns, index])
#     211
#     212
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1662         blocks = [getattr(b, "values", b) for b in blocks]
#    1663         tot_items = sum(b.shape[0] for b in blocks)
# -> 1664         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1665
#    1666
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in construction_error(tot_items, block_shape, axes, e)
#    1692     if block_shape[0] == 0:
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#    1696
#
# ValueError: Shape of passed values is (420, 1), indices imply (420, 2)

# %% [markdown]
# #  DATA ACQUISITION

# %% [markdown]
# # WORK ON THE DATA

# %% [raw]
# STEP 1 : remove all non-english tweets
# STEP 2 : divide the clean dataset into two parts - news and others

# %%
# STEP 1

def remove_nonenglish(data):
    for index, row in data.iterrows():
        i = index 
        try:
            a = detect(row["Text"])
            #print(a)
            b ='en'
            #print(index, row["Text"])
            if a == 'en':
                continue
            else:
                #print(index, row["Text"])
                #print(data.index[i])
                data.drop(data.index[i])
                continue
        except:
            a = "error"
            #print("Error in row ", i, '  ', row["Text"])
            data.drop(data.index[i])
            continue
            
    return data

# %%
# STEP 2

def divide_df(data):
    news_df = data.copy(deep= True)

    news_list = []

    for index, row in data.iterrows():
        i = index 
        substr ='news'
        substr1 ='News'
        substr2 = 'update'
        substr3 = 'China'
        string = row["User"]
        #print(string)


        if re.search(substr, string):
            news_list.append(string)
        elif re.search(substr1, string):
            news_list.append(string)
        elif re.search(substr2, string):
            news_list.append(string)
        elif re.search(substr3, string):
            news_list.append(string)
        else:
            continue




    #print(news_list)    

    news_df_news = news_df[news_df["User"].isin(news_list)]
    news_df_others = news_df[~news_df["User"].isin(news_list)]

    news =[news_df_news,news_df_others]

# %% [markdown]
# # GETTING THE DATA READY

# %% [raw]
# Datasets we are working on:
#     1. Hyderabad
#     2. All
#
# STEPS:
#     Step 1: dataset --> dataframe
#     Step 2: remove all non-english tweets, save dataframe

# %%
#HYDERABAD DATA 

hyderabad = pd.read_csv('hyderabad-og.csv')
hyderabad_clean = remove_nonenglish(hyderabad)

# %%
# ALL DATA 
hyderabad_clean.head(20)
# Out:
#     Unnamed: 0             User  \
# 0            0      G_K_Awasthi
# 1            1        shyamavta
# 2            2      arunava_leo
# 3            3  abdullah_rizwan
# 4            4       inLucidity
# 5            5   GaurangKharkar
# 6            6     PrisGalstaun
# 7            7      KeshvalaJay
# 8            8  Rajdeep50741845
# 9            9   UtpalBorpujari
# 10          10     DrPersistent
# 11          11  ahmedabadmirror
# 12          12       NishShreya
# 13          13   DemontTimothee
# 14          14       hency_shah
# 15          15  Saleh_Batlawala
# 16          16  derashriharshit
# 17          17     adityadeswal
# 18          18        imjkmehta
# 19          19      Iam_Sandy17
#
#                                                  Text  \
# 0   बे वजह घर से निकलने की ज़रूरत क्या है,मौत से आ...
# 1   मोदी जी आप जो ये 1000 रूपये देने वाले फार्म भर...
# 2   Lockdown was necessary. But how do daily worke...
# 3   This swamy somehow manages to speak the truth ...
# 4   क्यूँकि शौक़ कोरोना से भी बड़ी चीज़ है। :| #CO...
# 5   Last bench session before the lockdown.Somehow...
# 6   If the coronavirus doesn't kill them, Narendra...
# 7   ये मास्क देखते ही #corona ने इंडिया में आत्म ह...
# 8   Kirana stores deliver over e-comm apps in groc...
# 9   The housing society in my neighbourhood in #De...
# 10  #Covid19India #COVID #Corona Do not behave lik...
# 11  Using tobacco and drinking alcohol to cope wit...
# 12  कोरोना को हारने के लिए घर में सभी तैयारी कर ले...
# 13  Frightening #Covid19India story from @BBCWorld...
# 14  यह कोरोना चाईना ने ही बनाया ओर दुसरे देशों में...
# 15  Unless there is something communal, Media Chil...
# 16  खुद ही खुद के लिए, खुद ही खुद से, खुद ही खुद म...
# 17  Factories of non-essential goods r shut during...
# 18  @CMOMaharashtra @AjitPawarSpeaks @AnilDeshmukh...
# 19  People in Maharashtra found funny way to spend...
#
#                          Date  \
# 0   2020-03-31 23:43:48+00:00
# 1   2020-03-31 23:43:09+00:00
# 2   2020-03-31 23:35:16+00:00
# 3   2020-03-31 21:39:19+00:00
# 4   2020-03-31 21:15:14+00:00
# 5   2020-03-31 20:47:34+00:00
# 6   2020-03-31 20:46:41+00:00
# 7   2020-03-31 20:29:07+00:00
# 8   2020-03-31 20:24:25+00:00
# 9   2020-03-31 20:14:39+00:00
# 10  2020-03-31 20:12:42+00:00
# 11  2020-03-31 20:11:57+00:00
# 12  2020-03-31 20:08:14+00:00
# 13  2020-03-31 20:07:11+00:00
# 14  2020-03-31 19:46:34+00:00
# 15  2020-03-31 19:22:25+00:00
# 16  2020-03-31 19:22:16+00:00
# 17  2020-03-31 18:49:13+00:00
# 18  2020-03-31 18:48:20+00:00
# 19  2020-03-31 18:46:41+00:00
#
#                                              Hashtags
# 0              #Covid19India #CurfewInIndia #lockdown
# 1               #lockdown #NarendraModi #Covid19India
# 2                                       #Covid19India
# 3   #Lockdown21 #lockdown #Coronavirustruth #Covid...
# 4                      #COVID #lockdown #Covid19India
# 5   #powerlifting #fitness #gym #bodybuilding #wor...
# 6                                       #Covid19India
# 7   #corona #Coronavirustruth #Covid19India #lockdown
# 8   #lockdown #Covid19India #BigBasket #milkbasket...
# 9   #Delhi #COVID #StayHomeStaySafe #21DaysLockdow...
# 10  #Covid19India #COVID #Corona #StayAtHome #Stay...
# 11  #CautionYesPanicNo #Covid19India #IndiaFightsC...
# 12  #Coronavirustruth #Corona #IndiaFightsCorona #...
# 13                                      #Covid19India
# 14  #21dayslockdown #Covid19India #IndiaFightsAgai...
# 15  #Media_Virus #TabligiJamat #COVIDIDIOT #Lockdo...
# 16  #lockdown #QuarantineLife #poetry #Covid19Indi...
# 17                            #lockdown #Covid19India
# 18                               #COVID #Covid19India
# 19           #Mumbai #LockDown #Covid19India #Marathi

# %% [markdown]
# # TOPIC MODELING USING GENSIM

# %%
# import essentials


from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.utils import simple_preprocess, lemmatize
from nltk.corpus import stopwords
import re
import patterns
import logging
from gensim import corpora
from nltk.tokenize import word_tokenize
#from inltk.inltk import identify_language
#from inltk.inltk import setup
import re
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s')
logging.root.setLevel(level=logging.INFO)
stop_words = stopwords.words('english')
stop_words = stop_words + ['http']

# %%
# topic modeling

def topicmod(dataset):
    data = []
    badwords = ['https', 'ndtv', 'pmoinium','nitin_gadkari' , 'timesofindia', 'amp', '@', '']
    english ='en'
    indian_languages = 'hi|pa|sa|gu|kn|ml|ne|or|mr|bn|ta|ur'

    for d in dataset['Text']:
        try:
            if(detect(d)==english):


                for i in d.split():
                    if i.startswith("#") or i.startswith("@") or i.endswith(".com"):
                        d = d.replace(i,"")


                #print(d)
                for word in badwords:
                    if word in d:
                        #print(word)
                        d=d.replace(word,"")

                text = word_tokenize(d)
                data.append(text)
                    #print(text)
        except:
                continue
    
    stop_words = stopwords.words('english')

    data_processed = []

    for i, doc in enumerate(data[:3000]):
        doc_out = []
        for wd in doc: 
            #print(wd)
            if wd not in stop_words:  # remove stopwords
                lemmatized_word = lemmatize(wd, allowed_tags=re.compile('(NN|JJ|JJS|JJR|RB)'))  # lemmatize
                if lemmatized_word:
                    doc_out = doc_out + [lemmatized_word[0].split(b'/')[0].decode('utf-8')]
            else:
                continue
        data_processed.append(doc_out)

    # Print a small sample    
    #print(data_processed) 
    #type(data_processed)
    #> ['anarchism', 'originated', 'term', 'abuse', 'first']
    dct = corpora.Dictionary(data_processed)
    corpus = [dct.doc2bow(line) for line in data_processed]
    lda_model = LdaMulticore(corpus=corpus,
                         id2word=dct,
                         random_state=100,
                         num_topics=20,
                         passes=10,
                         chunksize=1000,
                         batch=False,
                         alpha='asymmetric',
                         decay=0.5,
                         offset=64,
                         eta=None,
                         eval_every=0,
                         iterations=100,
                         gamma_threshold=0.001,
                         per_word_topics=True)

    # save the model
    lda_model.save('lda_model.model')

    # See the topics
    lda_model.print_topics(-1)
    
    return lda_model

# %% [markdown]
# # VISUALISATION

# %% [raw]
# Methods used:
#     1. Wordcloud
#     2. Many-circle method

# %%
# 1. Wordcloud of Top N words in each topic
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

def wordcloud(lda_model):
    cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

    cloud = WordCloud(stopwords=stop_words,
                      background_color='white',
                      width=2500,
                      height=1800,
                      max_words=20,
                      colormap='tab10',
                      color_func=lambda *args, **kwargs: cols[i],
                      prefer_horizontal=1.0)

    topics = lda_model.show_topics(formatted=False)

    fig, axes = plt.subplots(2, 5, figsize=(10,10), sharex=True, sharey=True)

    for i, ax in enumerate(axes.flatten()):
        fig.add_subplot(ax)
        topic_words = dict(topics[i][1])
        cloud.generate_from_frequencies(topic_words, max_font_size=300)
        plt.gca().imshow(cloud)
        plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
        plt.gca().axis('off')


    plt.subplots_adjust(wspace=0, hspace=0)
    plt.axis('off')
    plt.margins(x=0, y=0)
    plt.tight_layout()
    plt.show()

# %%
# 2. Visualize the topics
import pyLDAvis.gensim
def vis2(lda_model):
    pyLDAvis.enable_notebook()
    vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
    vis

# %% [markdown]
# # DIVIDE INTO PHASES

# %% [raw]
# the entire dataset is divided into three sections:
#     1. Phase 1 - January to April
#     2. Phase 2 - April to June
#     3. Phase 3 - June to August

# %% [raw]
# STEPS :
#     Step 1 : convert datetime to date only (in the dataframe)
#     Step 2 : consoliated function for (topic modelling + visualisation)
#
#
#     Note - there are two functions for STEP 2
#            First, single split date
#            Second, split date with upper and lower limits

# %%
# Step 1 : convert datetime to just date in the dataframe

def date(dataframe):
    a = dataframe 

    a['Date'] = pd.to_datetime(a['Date'], errors='coerce')
    a['Date'] = a['Date'].dt.date
    dataframe_date = a
    
    return dataframe_date

# %%
#Step 2 : consolidated function

def phase_split1(df_date, split_date):
    
    df_final = df_date.loc[df_date['Date'] < split_date]

    topics = topicmod(df_final)
    wordcloud(topics)
    
def phase_split2(df_date, split_date_l,split_date_u):
    
    df_final = df_date.loc[(df_date['Date'] >= split_date_l) & (df_date['Date'] < split_date_u)]

    topics = topicmod(df_final)
    wordcloud(topics)
